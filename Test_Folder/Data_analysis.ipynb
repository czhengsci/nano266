# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

datafile = pd.read_csv('data_test_record_analysis_test.csv',header=0)

#Filter out H2 and N2 line using formation energy column NaN value
datafile = datafile[datafile.Formation_Enthalpy.notnull()]

# %%
dataframe_B3LYP = datafile[datafile.Functional_Used == 'B3LYP']

# %%
dataframe_B3LYP.plot(x='Basis_Set',y='Formation_Enthalpy')

# %%
list1 = dataframe_B3LYP['Basis_Set']

# %%
list1
# Out:
# 2     6-31+G*_6-31+G*_6-311+G*
# 5       6-31+G*_6-31+G*_6-311G
# 8       6-31+G*_6-31G_6-311+G*
# 11        6-31+G*_6-31G_6-311G
# 14      6-31G_6-31+G*_6-311+G*
# 17        6-31G_6-31+G*_6-311G
# 20        6-31G_6-31G_6-311+G*
# 23          6-31G_6-31G_6-311G
# Name: Basis_Set, dtype: object

# %%
plt.plot(dataframe_B3LYP['Basis_Set'],dataframe_B3LYP.Formation_Enthalpy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c6a1b4e72f21> in <module>()
# ----> 1 plt.plot(dataframe_B3LYP['Basis_Set'],dataframe_B3LYP.Formation_Enthalpy)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3091         ax.hold(hold)
#    3092     try:
# -> 3093         ret = ax.plot(*args, **kwargs)
#    3094         draw_if_interactive()
#    3095     finally:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1372
#    1373         for line in self._get_lines(*args, **kwargs):
# -> 1374             self.add_line(line)
#    1375             lines.append(line)
#    1376
#
# ...
